# %%
# !wget -O /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/dataset https://zenodo.org/records/6998936/files/signatures_dataset?download=1
# Out:
# zsh:1: no matches found: https://zenodo.org/records/6998936/files/signatures_dataset?download=1

# %%
# !unzip -d /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/dataset.zip
# Out:
# Archive:  /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/dataset.zip
#    creating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset
#    creating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT
#    creating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing
#   inflating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing/SA530_compare.tsv
#   inflating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing/SA1053_compare.tsv
#  extracting: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing/SA1181_compare.tsv
#   inflating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing/SA535_compare.tsv
#   inflating: /Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/ONT/phasing/SA039_compare.tsv
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/williams/signatures_dataset/DLP/SNV/snv_counts.csv.gz")
df
# Out:
# /var/folders/nz/jn74t1g51q10qyclfkkr8cgm0000gq/T/ipykernel_46688/3131680115.py:3: DtypeWarning: Columns (26,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/williams/signatures_dataset/DLP/SNV/snv_counts.csv.gz")
#          chr     start ref alt                         cell_id patient  \
# 0          1   2901334   A   T  SA604X6XB01972-A96177C-R55-C31   SA604
# 1          1   4724917   C   G  SA604X6XB01972-A96177C-R55-C31   SA604
# 2          1   5404076   A   T  SA604X6XB01972-A96177C-R55-C31   SA604
# 3          1   6303195   T   G  SA604X6XB01972-A96177C-R55-C31   SA604
# 4          1  11585442   G   T  SA604X6XB01972-A96177C-R55-C31   SA604
# ...       ..       ...  ..  ..                             ...     ...
# 31385546   6  54625196   T   C          AT135-A118389B-R65-C67  SA1292
# 31385547   6  70850297   T   G          AT135-A118389B-R65-C67  SA1292
# ...

# %%
df.columns
# Out:
# Index(['chr', 'start', 'ref', 'alt', 'cell_id', 'patient', 'endy', 'state',
#        'copy', 'state_AS_phased', 'alleleA', 'alleleB', 'totalcounts', 'BAF',
#        'state_min', 'Maj', 'Min', 'LOH', 'phase', 'state_phase', 'state_BAF',
#        'ref_counts', 'alt_counts', 'sample_id', 'library_id', 'total_counts',
#        'isabl_patient_id', 'isabl_sample_id', 'isabl_aliquot_id',
#        'i.isabl_patient_id', 'i.isabl_sample_id', 'i.isabl_aliquot_id'],
#       dtype='object')

# %%
df = pd.read_csv("/Users/samin/workspace/scWGS-Tumor-Phylogeny/data/williams/signatures_dataset/DLP/CNA/persample/SA039_hscn.csv.gz")
df
# Out:
#         patient                 cell_id chr      start        end  state  \
# 0        OV2295  SA1090-A96213A-R20-C11   1          1     500000      2
# 1        OV2295  SA1090-A96213A-R20-C11   1     500001    1000000      2
# 2        OV2295  SA1090-A96213A-R20-C11   1    1000001    1500000      2
# 3        OV2295  SA1090-A96213A-R20-C11   1    1500001    2000000      2
# 4        OV2295  SA1090-A96213A-R20-C11   1    2000001    2500000      2
# ...         ...                     ...  ..        ...        ...    ...
# 6598303  OV2295   SA922-A90554B-R35-C69   X  153000001  153500000      2
# 6598304  OV2295   SA922-A90554B-R35-C69   X  153500001  154000000      2
# 6598305  OV2295   SA922-A90554B-R35-C69   X  154000001  154500000      2
# 6598306  OV2295   SA922-A90554B-R35-C69   X  154500001  155000000      2
# 6598307  OV2295   SA922-A90554B-R35-C69   X  155000001  155500000      2
#
#              copy state_AS_phased  alleleA  alleleB  totalcounts  BAF  \
# ...

# %%
df.columns
# Out:
# Index(['patient', 'cell_id', 'chr', 'start', 'end', 'state', 'copy',
#        'state_AS_phased', 'alleleA', 'alleleB', 'totalcounts', 'BAF',
#        'state_min', 'Maj', 'Min', 'LOH', 'phase', 'state_phase', 'state_BAF'],
#       dtype='object')

# %%
df = pd.read_csv("../data/williams/signatures_dataset/DLP/CNA/hscn_clones.csv.gz")
df
# Out:
#         patient clone_id chr      start          end  state      copy  Min  \
# 0         SA604        N   1          1     500000.0      4       NaN    0
# 1         SA604        N   1     500001    1000000.0      4       NaN    0
# 2         SA604        N   1    1000001    1500000.0      4  3.291465    0
# 3         SA604        N   1    1500001    2000000.0      4  3.182206    0
# 4         SA604        N   1    2000001    2500000.0      4  3.687108    0
# ...         ...      ...  ..        ...          ...    ...       ...  ...
# 1661746  SA1292        C   X  153000001  153500000.0      2  1.756041    1
# 1661747  SA1292        C   X  153500001  154000000.0      2  1.569689    1
# 1661748  SA1292        C   X  154000001  154500000.0      2  2.151393    1
# 1661749  SA1292        C   X  154500001  155000000.0      2  1.475498    1
# 1661750  SA1292        C   X  155000001  155500000.0      2       NaN    1
#
# ...

# %%
df[df['patient'] == 'SA906a']['clone_id'].unique()
# Out:
# array(['C', 'L', 'D', 'H', 'M', 'J', 'G', 'K', 'B', 'I', 'E', nan, 'A',
#        'F'], dtype=object)
