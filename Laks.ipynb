# %%
# !wget https://zenodo.org/api/records/3445364/files-archive -O archive.zip
# Out:
# --2025-06-25 16:43:23--  https://zenodo.org/api/records/3445364/files-archive
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.45.92, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘archive.zip’
#
# archive.zip             [               <=>  ] 194.57M  59.3MB/s    in 3.7s
#
# 2025-06-25 16:43:27 (52.9 MB/s) - ‘archive.zip’ saved [204018658]

# %%
# !mkdir data
# !unzip archive.zip -d data/
# Out:
# Archive:  archive.zip
#  extracting: data/ov2295_clone_clusters.csv.gz
#  extracting: data/ov2295_clone_snvs.csv.gz
#  extracting: data/ov_supp_clone_allele_cn.png
#  extracting: data/ov2295_cell_metrics.csv.gz
#  extracting: data/ov2295_clone_alleles.csv.gz
#  extracting: data/ov2295_clone_breakpoints.csv.gz
#  extracting: data/ov2295_nodes.csv.gz
#  extracting: data/ov2295_cell_cn.csv.gz
#  extracting: data/ov2295_tree.pickle
#  extracting: data/ov2295_breakpoint_counts.csv.gz
#  extracting: data/ov2295_clone_cn.csv.gz
#  extracting: data/ov2295_snv_counts.csv.gz
#  extracting: data/ov_supp_sample_total_cn.png
#  extracting: data/ov_supp_sample_allele_cn.png
#  extracting: data/ov_supp_clone_total_cn.png

# %%
import pandas as pd

# %%
ROOT_DIR = "data/"

# %%
import pandas as pd

# %%
df_clone_clusters = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_clusters.csv.gz")
df_clone_clusters.sort_values(by='cell_id')
# Out:
#                     cell_id clone_id
# 0    SA1090-A96213A-R20-C09        C
# 1    SA1090-A96213A-R20-C11        C
# 99   SA1090-A96213A-R20-C12        D
# 209  SA1090-A96213A-R20-C13        A
# 335  SA1090-A96213A-R20-C17        B
# ..                      ...      ...
# 812   SA922-A90554B-R35-C45        E
# 813   SA922-A90554B-R35-C49        E
# 890   SA922-A90554B-R35-C56        F
# 814   SA922-A90554B-R35-C65        E
# 815   SA922-A90554B-R35-C69        E
#
# [891 rows x 2 columns]

# %%
df_clone_snvs = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_snvs.csv.gz")
df_clone_snvs
# Out:
# /tmp/ipython-input-7-3941203960.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clone_snvs = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_snvs.csv.gz")
#        chrom      coord ref alt clone_id  ref_counts  alt_counts  \
# 0          1     985349   G   A        A          18           0
# 1          1     985349   G   A        B          19           0
# 2          1     985349   G   A        C          14           0
# 3          1     985349   G   A        D          18           0
# 4          1     985349   G   A        E           6          10
# ...      ...        ...  ..  ..      ...         ...         ...
# 126607     X  154563943   T   A        E           0          10
# 126608     X  154563943   T   A        F           0          10
# 126609     X  154563943   T   A        G          22           0
# 126610     X  154563943   T   A        H          10           0
# 126611     X  154563943   T   A        I          15           0
#
#         total_counts  is_present  is_het  is_hom
# 0                 18           0       0       0
# 1                 19           0       0       0
# 2                 14           0       0       0
# 3                 18           0       0       0
# 4                 23           1       1       0
# ...              ...         ...     ...     ...
# 126607            13           1       1       0
# 126608            14           1       1       0
# 126609            22           0       0       0
# 126610            10           0       0       0
# 126611            15           0       0       0
#
# [126612 rows x 11 columns]

# %%
df_cell_metrics = pd.read_csv(f"{ROOT_DIR}/ov2295_cell_metrics.csv.gz")
df_cell_metrics.sort_values(by='cell_id')
# Out:
#                      cell_id  unpaired_mapped_reads  paired_mapped_reads  \
# 1813  SA1090-A96213A-R20-C06                    184                 3736
# 1943  SA1090-A96213A-R20-C08                  54091              3043249
# 1942  SA1090-A96213A-R20-C09                  46152              2446667
# 1743  SA1090-A96213A-R20-C10                  38862              1861172
# 1744  SA1090-A96213A-R20-C11                  36552              1853015
# ...                      ...                    ...                  ...
# 551    SA922-A90554B-R35-C66                  79455              3456790
# 552    SA922-A90554B-R35-C67                 101819              4285100
# 549    SA922-A90554B-R35-C68                  84486              3523839
# 550    SA922-A90554B-R35-C69                  86666              3724589
# 384    SA922-A90554B-R35-C70                  63093              2363211
#
#       unpaired_duplicate_reads  paired_duplicate_reads  unmapped_reads  \
# 1813                         5                     266            6334
# 1943                     19530                  742185          472144
# 1942                     17898                  623318          425083
# 1743                     13768                  399894          356296
# 1744                     12832                  419203          316488
# ...                        ...                     ...             ...
# 551                      25087                 1056272          482311
# 552                      37573                 1212820          714732
# 549                      25999                 1055960          486692
# 550                      30366                 1106918          561420
# 384                      16972                  672705          328137
#
#       percent_duplicate_reads  estimated_library_size  total_reads  \
# 1813                 0.077194                 27529.0        13990
# 1943                 0.252609               5292268.0      6612734
# 1942                 0.264365               4035413.0      5364570
# 1743                 0.223501               3777751.0      4117502
# 1744                 0.235082               3536337.0      4059070
# ...                       ...                     ...          ...
# 551                  0.307324               4447773.0      7475346
# 552                  0.285437               6080607.0      9386752
# 549                  0.301334               4649553.0      7618856
# 550                  0.299257               4965940.0      8097264
# 384                  0.285923               3329692.0      5117652
#
#       total_mapped_reads  ...  mean_state_mads  mean_state_vars  \
# 1813                7656  ...     8.801079e-09         0.277387
# 1943             6140590  ...     1.355167e-01         0.346735
# 1942             4939487  ...     4.291251e-02         0.025927
# 1743             3761206  ...     1.634896e+01       778.018305
# 1744             3742582  ...     5.451228e-02         0.042987
# ...                  ...  ...              ...              ...
# 551              6993035  ...     1.142069e-01         0.741109
# 552              8672020  ...     6.870316e-02         0.302356
# 549              7132164  ...     1.338978e-01         0.567978
# 550              7535844  ...     6.166354e-02         0.264466
# 384              4789515  ...     1.483045e-01         1.227284
#
#       mad_neutral_state  breakpoints  mean_copy  state_mode  log_likelihood  \
# 1813       6.612847e-09         1105   2.694481           2     3442.321452
# 1943       8.130422e-02          516   2.553902           3    -4764.668175
# 1942       4.776725e-02           89   1.885592           2     1966.597083
# 1743                NaN           15  71.649775           8   -26641.531423
# 1744       5.850109e-02           89   1.885018           2     1008.649751
# ...                 ...          ...        ...         ...             ...
# 551        7.613230e-02          336   4.721971           4    -6801.301540
# 552        4.494102e-02           93   4.130080           5    -3484.153571
# 549        9.340366e-02          282   3.774048           3    -6202.957887
# 550        4.366547e-02           98   4.152376           5    -3388.313212
# 384        7.630752e-02          187   5.578105           4    -8103.809644
#
#      true_multiplier  quality  order
# 1813        2.000000    0.000  666.0
# 1943        1.985751    0.458  780.0
# 1942        1.999676    0.998  308.0
# 1743        0.777111    0.042  886.0
# 1744        2.002452    1.000  296.0
# ...              ...      ...    ...
# 551         4.025640    0.334  202.0
# 552         3.986422    0.962  258.0
# 549         2.959775    0.422  399.0
# 550         4.161776    0.968  546.0
# 384         4.031511    0.556  116.0
#
# [1966 rows x 55 columns]

# %%
df_clone_alleles = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_alleles.csv.gz")
df_clone_alleles
# Out:
# /tmp/ipython-input-9-1488976780.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clone_alleles = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_alleles.csv.gz")
#        chr      start        end  hap_label clone_id  allele_1_sum  \
# 0       10          1     500000          0        E            21
# 1       10          1     500000          1        E            18
# 2       10          1     500000          2        E           577
# 3       10          1     500000          3        E            10
# 4       10          1     500000          4        E           418
# ...     ..        ...        ...        ...      ...           ...
# 983674  12  133500001  134000000       4989        B             1
# 983675  12  133500001  134000000       4990        B             9
# 983676  12  133500001  134000000       4992        B             0
# 983677  12  133500001  134000000       4993        B             9
# 983678  12  133500001  134000000       4994        B             2
#
#         allele_2_sum  total_counts_sum
# 0                  1                22
# 1                 15                33
# 2                516              1093
# 3                 30                40
# 4                140               558
# ...              ...               ...
# 983674             0                 1
# 983675             0                 9
# 983676            11                11
# 983677             0                 9
# 983678             4                 6
#
# [983679 rows x 8 columns]

# %%
df_clone_brkpts = pd.read_csv(f"{ROOT_DIR}/ov2295_clone_breakpoints.csv.gz")
df_clone_brkpts
# Out:
#      chromosome_1 strand_1  position_1 chromosome_2 strand_2  position_2  \
# 0               1        +     2242767            1        +     2242735
# 1               1        +     2242767            1        +     2242735
# 2               1        +     2242767            1        +     2242735
# 3               1        +     2242767            1        +     2242735
# 4               1        +     2242767            1        +     2242735
# ...           ...      ...         ...          ...      ...         ...
# 4837            X        -   134340688           16        -    89819282
# 4838            X        -   134340688           16        -    89819282
# 4839            X        -   134340688           16        -    89819282
# 4840            X        -   134340688           16        -    89819282
# 4841            X        -   134340688           16        -    89819282
#
#      clone_id  read_count  is_present
# 0           A           0       False
# 1           B           0       False
# 2           C           0       False
# 3           D           0       False
# 4           E           4        True
# ...       ...         ...         ...
# 4837        E           3        True
# 4838        F           0       False
# 4839        G           0       False
# 4840        H           0       False
# 4841        I           0       False
#
# [4842 rows x 9 columns]

# %%
df_nodes = pd.read_csv(f"{ROOT_DIR}/ov2295_nodes.csv.gz")
df_nodes
# Out:
#               variant_id  node           loss        origin      presence  \
# 0       10:100129846:C:A     0   0.000000e+00  4.573674e-05  0.000000e+00
# 1       10:100129846:C:A     1   4.542663e-05  3.979706e-41  3.101192e-07
# 2       10:100129846:C:A     2   3.080443e-07  3.926630e-41  2.074915e-09
# 3       10:100129846:C:A     3   2.074915e-09  8.623432e-67  0.000000e+00
# 4       10:100129846:C:A     4   2.074915e-09  8.588990e-55  0.000000e+00
# ...                  ...   ...            ...           ...           ...
# 239151    X:99571629:G:T    12  4.783274e-116  9.932175e-01  6.782464e-03
# 239152    X:99571629:G:T    13   6.894618e-84  1.015949e-30  1.000000e+00
# 239153    X:99571629:G:T    14   6.980025e-69  1.003518e-45  1.000000e+00
# 239154    X:99571629:G:T    15   6.653350e-18  1.052790e-96  1.000000e+00
# 239155    X:99571629:G:T    16   6.889929e-33  1.016640e-81  1.000000e+00
#
#         ml_origin  ml_presence  ml_loss
# 0               0            0        0
# 1               0            0        0
# 2               0            0        0
# 3               0            0        0
# 4               0            0        0
# ...           ...          ...      ...
# 239151          1            1        0
# 239152          0            1        0
# 239153          0            1        0
# 239154          0            1        0
# 239155          0            1        0
#
# [239156 rows x 8 columns]

# %%
df_cell_cn = pd.read_csv(f"{ROOT_DIR}/ov2295_cell_cn.csv.gz")
df_cell_cn.sort_values(by=['cell_id', 'chr', 'start'])
# Out:
#                          cell_id sample_id library_id chr     start       end  \
# 11251478  SA1090-A96213A-R20-C06    SA1090    A96213A   1         1    500000
# 11251479  SA1090-A96213A-R20-C06    SA1090    A96213A   1    500001   1000000
# 11251480  SA1090-A96213A-R20-C06    SA1090    A96213A   1   1000001   1500000
# 11251481  SA1090-A96213A-R20-C06    SA1090    A96213A   1   1500001   2000000
# 11251482  SA1090-A96213A-R20-C06    SA1090    A96213A   1   2000001   2500000
# ...                          ...       ...        ...  ..       ...       ...
# 2389305    SA922-A90554B-R35-C70     SA922    A90554B   Y  57000001  57500000
# 2389306    SA922-A90554B-R35-C70     SA922    A90554B   Y  57500001  58000000
# 2389307    SA922-A90554B-R35-C70     SA922    A90554B   Y  58000001  58500000
# 2389308    SA922-A90554B-R35-C70     SA922    A90554B   Y  58500001  59000000
# 2389309    SA922-A90554B-R35-C70     SA922    A90554B   Y  59000001  59500000
#
#           reads  copy  state
# 11251478      0   NaN      2
# 11251479      0   NaN      2
# 11251480      2   2.0      2
# 11251481      2   2.0      2
# 11251482      2   2.0      2
# ...         ...   ...    ...
# 2389305       0   NaN      0
# 2389306       0   NaN      0
# 2389307       0   NaN      0
# 2389308      44   NaN      0
# 2389309      51   NaN      0
#
# [12200996 rows x 9 columns]

# %%
df_snv_cnts = pd.read_csv(f"{ROOT_DIR}/ov2295_snv_counts.csv.gz")
df_snv_cnts.sort_values(by=['cell_id', 'chrom', 'coord'])
# Out:
# /tmp/ipython-input-13-73620266.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_snv_cnts = pd.read_csv(f"{ROOT_DIR}/ov2295_snv_counts.csv.gz")
#         chrom      coord ref alt  ref_counts  alt_counts  \
# 1865856     4  167583433   C   G           1           0
# 2456293     8   91421823   G   A           1           0
# 2790188     X  115536353   T   A           0           2
# 12063       1    5033682   G   T           2           0
# 13465       1   14698964   A   C           1           0
# ...       ...        ...  ..  ..         ...         ...
# 3254567     X  127536948   G   A           0           1
# 993271      X  138263040   A   T           0           1
# 2084770     X  138270131   T   C           1           0
# 993588      X  143780999   C   A           0           2
# 3479870     X  149425951   A   G           0           1
#
#                         cell_id  total_counts sample_id
# 1865856  SA1090-A96213A-R20-C06             1    SA1090
# 2456293  SA1090-A96213A-R20-C06             1    SA1090
# 2790188  SA1090-A96213A-R20-C06             2    SA1090
# 12063    SA1090-A96213A-R20-C08             2    SA1090
# 13465    SA1090-A96213A-R20-C08             1    SA1090
# ...                         ...           ...       ...
# 3254567   SA922-A90554B-R35-C70             1     SA922
# 993271    SA922-A90554B-R35-C70             1     SA922
# 2084770   SA922-A90554B-R35-C70             1     SA922
# 993588    SA922-A90554B-R35-C70             2     SA922
# 3479870   SA922-A90554B-R35-C70             1     SA922
#
# [3800284 rows x 9 columns]

# %%
import pickle

with open(f"{ROOT_DIR}/ov2295_tree.pickle", "rb") as f:
    data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-14-3362831030.py in <cell line: 0>()
#       2
#       3 with open(f"{ROOT_DIR}/ov2295_tree.pickle", "rb") as f:
# ----> 4     data = pickle.load(f)
#
# ModuleNotFoundError: No module named 'dollo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread(f'{ROOT_DIR}/ov_supp_clone_allele_cn.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(f'{ROOT_DIR}/ov_supp_sample_total_cn.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(f'{ROOT_DIR}/ov_supp_sample_allele_cn.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(f'{ROOT_DIR}/ov_supp_clone_total_cn.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Pooling

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import SpectralBiclustering

# %%
df = df_clone_snvs
df["mutation"] = df["chrom"].astype(str) + ":" + df["coord"].astype(str) + ":" + df["ref"].astype(str) + ":" + df["alt"].astype(str)
df_clone_snvs
# Out:
#        chrom      coord ref alt clone_id  ref_counts  alt_counts  \
# 0          1     985349   G   A        A          18           0
# 1          1     985349   G   A        B          19           0
# 2          1     985349   G   A        C          14           0
# 3          1     985349   G   A        D          18           0
# 4          1     985349   G   A        E           6          10
# ...      ...        ...  ..  ..      ...         ...         ...
# 126607     X  154563943   T   A        E           0          10
# 126608     X  154563943   T   A        F           0          10
# 126609     X  154563943   T   A        G          22           0
# 126610     X  154563943   T   A        H          10           0
# 126611     X  154563943   T   A        I          15           0
#
#         total_counts  is_present  is_het  is_hom         mutation
# 0                 18           0       0       0     1:985349:G:A
# 1                 19           0       0       0     1:985349:G:A
# 2                 14           0       0       0     1:985349:G:A
# 3                 18           0       0       0     1:985349:G:A
# 4                 23           1       1       0     1:985349:G:A
# ...              ...         ...     ...     ...              ...
# 126607            13           1       1       0  X:154563943:T:A
# 126608            14           1       1       0  X:154563943:T:A
# 126609            22           0       0       0  X:154563943:T:A
# 126610            10           0       0       0  X:154563943:T:A
# 126611            15           0       0       0  X:154563943:T:A
#
# [126612 rows x 12 columns]

# %%
total_table = df_clone_snvs.pivot_table(
    index='clone_id',
    columns='mutation',
    values='total_counts',
    aggfunc='sum',
    fill_value=0
)
total_table
# Out:
# mutation  10:100129846:C:A  10:100185101:A:G  10:100209326:T:C  \
# clone_id
# A                       10                21                 5
# B                        6                13                 7
# C                       13                11                 6
# D                       13                15                 5
# E                       27                35                27
# F                       16                18                15
# G                       18                16                16
# H                       14                18                16
# I                       24                19                19
#
# mutation  10:100283942:C:T  10:10086005:G:T  10:100873589:A:T  \
# clone_id
# A                       24               24                 6
# B                       16               30                 5
# C                        8               23                 4
# D                       26               36                10
# E                       51               54                26
# F                       30               24                21
# G                       42               45                23
# H                       22               20                13
# I                       32               26                21
#
# mutation  10:101108222:C:A  10:101108223:T:C  10:101427318:G:C  \
# clone_id
# A                       24                24                14
# B                        9                10                12
# C                       15                15                 5
# D                       19                19                11
# E                       64                64                66
# F                       31                31                29
# G                       38                38                52
# H                       23                23                21
# I                       31                32                30
#
# mutation  10:101884473:T:A  ...  X:97291714:A:T  X:97396419:C:A  \
# clone_id                    ...
# A                        5  ...               8              11
# B                        6  ...               7              12
# C                        5  ...               6              12
# D                        9  ...               4               8
# E                       22  ...              15              26
# F                       12  ...              11              12
# G                       10  ...              12              12
# H                       13  ...              13               5
# I                       14  ...              13              18
#
# mutation  X:97564955:T:C  X:97583306:G:T  X:98177771:A:C  X:98278474:C:A  \
# clone_id
# A                      6              23               7              11
# B                      7               5               3               9
# C                      4               8               4              11
# D                      8               7              18              20
# E                     21              18              30              27
# F                      2              16              12               8
# G                      9              13              20              19
# H                      8               6               5              11
# I                      7              10              23               8
#
# mutation  X:98452192:T:C  X:98700894:C:T  X:99136386:C:T  X:99571629:G:T
# clone_id
# A                      8               1              20               3
# B                      6               3               8               9
# C                      5               4               6              10
# D                      8               7              12               7
# E                     13              21              20              28
# F                      7              13               7              12
# G                      7              17              11              22
# H                      8              10               7               5
# I                      8               9              10              10
#
# [9 rows x 14068 columns]

# %%
alt_table = df.pivot_table(
    index='clone_id',
    columns='mutation',
    values='alt_counts',
    aggfunc='sum',
    fill_value=0
)
alt_table
# Out:
# mutation  10:100129846:C:A  10:100185101:A:G  10:100209326:T:C  \
# clone_id
# A                        0                 0                 5
# B                        0                 0                 7
# C                        0                 0                 6
# D                        0                 0                 5
# E                       10                10                 9
# F                        4                10                10
# G                        0                 0                 7
# H                        0                 0                 9
# I                        0                 0                10
#
# mutation  10:100283942:C:T  10:10086005:G:T  10:100873589:A:T  \
# clone_id
# A                        0               10                 0
# B                        0               10                 0
# C                        0                0                 0
# D                        0                0                 0
# E                       10                0                 7
# F                       10                0                 1
# G                        0                0                 0
# H                        0                0                 0
# I                        0                0                 0
#
# mutation  10:101108222:C:A  10:101108223:T:C  10:101427318:G:C  \
# clone_id
# A                        0                 0                 0
# B                        0                 0                 0
# C                        1                 0                 0
# D                        0                 0                 0
# E                       10                10                10
# F                       10                10                 0
# G                        0                 0                 0
# H                        1                 0                 0
# I                        0                 0                 0
#
# mutation  10:101884473:T:A  ...  X:97291714:A:T  X:97396419:C:A  \
# clone_id                    ...
# A                        5  ...               0               0
# B                        6  ...               0               0
# C                        5  ...               0               0
# D                        9  ...               0               0
# E                       10  ...               0              10
# F                        5  ...               0               0
# G                        3  ...              10               0
# H                        8  ...              10               0
# I                        7  ...              10               0
#
# mutation  X:97564955:T:C  X:97583306:G:T  X:98177771:A:C  X:98278474:C:A  \
# clone_id
# A                      0              10               7               0
# B                      0               4               3               0
# C                      0               0               4               0
# D                      0               0              10               0
# E                      1               0              10               0
# F                      0               0              10               0
# G                      9               0              10               8
# H                      8               0               5               5
# I                      7               0              10               1
#
# mutation  X:98452192:T:C  X:98700894:C:T  X:99136386:C:T  X:99571629:G:T
# clone_id
# A                      0               1               0               0
# B                      0               3               0               0
# C                      5               4               0               0
# D                      8               7               0               0
# E                      0              10              10               0
# F                      0              10               7               0
# G                      0              10               0              10
# H                      0              10               0               5
# I                      0               9               0              10
#
# [9 rows x 14068 columns]

# %%
frac_table = alt_table.div(total_table).replace(np.nan, 0)
frac_table
# Out:
# mutation  10:100129846:C:A  10:100185101:A:G  10:100209326:T:C  \
# clone_id
# A                  0.00000          0.000000          1.000000
# B                  0.00000          0.000000          1.000000
# C                  0.00000          0.000000          1.000000
# D                  0.00000          0.000000          1.000000
# E                  0.37037          0.285714          0.333333
# F                  0.25000          0.555556          0.666667
# G                  0.00000          0.000000          0.437500
# H                  0.00000          0.000000          0.562500
# I                  0.00000          0.000000          0.526316
#
# mutation  10:100283942:C:T  10:10086005:G:T  10:100873589:A:T  \
# clone_id
# A                 0.000000         0.416667          0.000000
# B                 0.000000         0.333333          0.000000
# C                 0.000000         0.000000          0.000000
# D                 0.000000         0.000000          0.000000
# E                 0.196078         0.000000          0.269231
# F                 0.333333         0.000000          0.047619
# G                 0.000000         0.000000          0.000000
# H                 0.000000         0.000000          0.000000
# I                 0.000000         0.000000          0.000000
#
# mutation  10:101108222:C:A  10:101108223:T:C  10:101427318:G:C  \
# clone_id
# A                 0.000000          0.000000          0.000000
# B                 0.000000          0.000000          0.000000
# C                 0.066667          0.000000          0.000000
# D                 0.000000          0.000000          0.000000
# E                 0.156250          0.156250          0.151515
# F                 0.322581          0.322581          0.000000
# G                 0.000000          0.000000          0.000000
# H                 0.043478          0.000000          0.000000
# I                 0.000000          0.000000          0.000000
#
# mutation  10:101884473:T:A  ...  X:97291714:A:T  X:97396419:C:A  \
# clone_id                    ...
# A                 1.000000  ...        0.000000        0.000000
# B                 1.000000  ...        0.000000        0.000000
# C                 1.000000  ...        0.000000        0.000000
# D                 1.000000  ...        0.000000        0.000000
# E                 0.454545  ...        0.000000        0.384615
# F                 0.416667  ...        0.000000        0.000000
# G                 0.300000  ...        0.833333        0.000000
# H                 0.615385  ...        0.769231        0.000000
# I                 0.500000  ...        0.769231        0.000000
#
# mutation  X:97564955:T:C  X:97583306:G:T  X:98177771:A:C  X:98278474:C:A  \
# clone_id
# A               0.000000        0.434783        1.000000        0.000000
# B               0.000000        0.800000        1.000000        0.000000
# C               0.000000        0.000000        1.000000        0.000000
# D               0.000000        0.000000        0.555556        0.000000
# E               0.047619        0.000000        0.333333        0.000000
# F               0.000000        0.000000        0.833333        0.000000
# G               1.000000        0.000000        0.500000        0.421053
# H               1.000000        0.000000        1.000000        0.454545
# I               1.000000        0.000000        0.434783        0.125000
#
# mutation  X:98452192:T:C  X:98700894:C:T  X:99136386:C:T  X:99571629:G:T
# clone_id
# A                    0.0        1.000000             0.0        0.000000
# B                    0.0        1.000000             0.0        0.000000
# C                    1.0        1.000000             0.0        0.000000
# D                    1.0        1.000000             0.0        0.000000
# E                    0.0        0.476190             0.5        0.000000
# F                    0.0        0.769231             1.0        0.000000
# G                    0.0        0.588235             0.0        0.454545
# H                    0.0        1.000000             0.0        1.000000
# I                    0.0        1.000000             0.0        1.000000
#
# [9 rows x 14068 columns]

# %%
import numpy as np

print("Any NaNs:", frac_table.isna().values.any())
print("Any +inf:", np.isinf(frac_table.values).any())
print("Any -inf:", np.isneginf(frac_table.values).any())

print(frac_table.dtypes)
# Out:
# Any NaNs: False
# Any +inf: False
# Any -inf: False
# mutation
# 10:100129846:C:A    float64
# 10:100185101:A:G    float64
# 10:100209326:T:C    float64
# 10:100283942:C:T    float64
# 10:10086005:G:T     float64
#                      ...
# X:98278474:C:A      float64
# X:98452192:T:C      float64
# X:98700894:C:T      float64
# X:99136386:C:T      float64
# X:99571629:G:T      float64
# Length: 14068, dtype: object

# %%
from sklearn.cluster import SpectralBiclustering
import numpy as np

model = SpectralBiclustering(n_clusters=5, method='log', random_state=0)
model.fit(frac_table.values)

# Reorder matrix by clusters
frac_biclust = frac_table.iloc[np.argsort(model.row_labels_)]
frac_biclust = frac_biclust.iloc[:, np.argsort(model.column_labels_)]

# %%
import seaborn as sns
sns.heatmap(frac_biclust, cmap='coolwarm')
# Out:
# <Axes: xlabel='mutation', ylabel='clone_id'>

# %%
# Get where the cluster boundaries are
row_clusters, row_counts = np.unique(model.row_labels_[row_order], return_counts=True)
col_clusters, col_counts = np.unique(model.column_labels_[col_order], return_counts=True)

row_lines = np.cumsum(row_counts)[:-1]
col_lines = np.cumsum(col_counts)[:-1]

# Plot with boundaries
plt.figure(figsize=(12, 10))
ax = sns.heatmap(frac_biclust, cmap='viridis', cbar=True)

# Draw horizontal lines
for r in row_lines:
    ax.axhline(r, color='white', lw=2)

# Draw vertical lines
for c in col_lines:
    ax.axvline(c, color='white', lw=2)

plt.title("Spectral Biclustering of Variant Fraction")
plt.xlabel("Mutations")
plt.ylabel("Clone IDs")
plt.show()

# %%
df = df_snv_cnts
df["mutation"] = df["chrom"].astype(str) + ":" + df["coord"].astype(str) + ":" + df["ref"].astype(str) + ":" + df["alt"].astype(str)
df_snv_cnts
# Out:
#         chrom     coord ref alt  ref_counts  alt_counts  \
# 0           1  19671432   C   T           1           0
# 1           1  19671432   C   T           2           0
# 2           1  19671432   C   T           1           0
# 3           1  19671432   C   T           2           0
# 4           1  19671432   C   T           1           0
# ...       ...       ...  ..  ..         ...         ...
# 3800279     5  62716827   T   A           1           0
# 3800280     5  62716827   T   A           1           0
# 3800281     5  62716827   T   A           1           0
# 3800282     5  62716827   T   A           1           0
# 3800283     5  62716827   T   A           1           0
#
#                         cell_id  total_counts sample_id        mutation
# 0         SA921-A90554A-R03-C03             1     SA921  1:19671432:C:T
# 1         SA921-A90554A-R03-C13             2     SA921  1:19671432:C:T
# 2         SA921-A90554A-R03-C21             1     SA921  1:19671432:C:T
# 3         SA921-A90554A-R03-C68             2     SA921  1:19671432:C:T
# 4         SA921-A90554A-R04-C10             1     SA921  1:19671432:C:T
# ...                         ...           ...       ...             ...
# 3800279  SA1090-A96213A-R27-C49             1    SA1090  5:62716827:T:A
# 3800280  SA1090-A96213A-R30-C14             1    SA1090  5:62716827:T:A
# 3800281  SA1090-A96213A-R30-C15             1    SA1090  5:62716827:T:A
# 3800282  SA1090-A96213A-R33-C10             1    SA1090  5:62716827:T:A
# 3800283  SA1090-A96213A-R34-C24             1    SA1090  5:62716827:T:A
#
# [3800284 rows x 10 columns]

# %%
total_cells = len(df_snv_cnts["cell_id"].unique())
total_mutations = len(df_snv_cnts["mutation"].unique())

max_reads = total_cells * total_mutations

total_reads = np.sum(df_snv_cnts["total_counts"])

read_depths = total_reads / max_reads

print(read_depths)
# Out:
# 0.1999544232696098

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is called df

# Histogram 1: Read depths per mutation
mutation_read_depths = df_snv_cnts.groupby("mutation")["total_counts"].sum()

plt.figure(figsize=(10, 5))
sns.histplot(mutation_read_depths / total_cells, bins=50, kde=True)
plt.title("Histogram of Read Depth per Mutation")
plt.xlabel("Read Depth")
plt.ylabel("Number of Mutations")
plt.tight_layout()
plt.show()

# Histogram 2: Read depths per cell
cell_read_depths = df_snv_cnts.groupby("cell_id")["total_counts"].sum()

plt.figure(figsize=(10, 5))
sns.histplot(cell_read_depths / total_mutations, bins=50, kde=True)
plt.title("Histogram of Read Depth per Cell")
plt.xlabel("Read Depth")
plt.ylabel("Number of Cells")
plt.tight_layout()
plt.show()
